# %%
import pandas as pd

# %%
acs02_2022 = pd.read_csv('ACS Data/DP02_2022.csv', low_memory=False)
acs03_2022 = pd.read_csv('ACS Data/DP03_2022.csv', low_memory=False)
acs04_2022 = pd.read_csv('ACS Data/DP04_2022.csv', low_memory=False)
acs05_2022 = pd.read_csv('ACS Data/DP05_2022.csv', low_memory=False)

acs02_2010 = pd.read_csv('ACS Data/DP02_2010.csv', low_memory=False)
acs03_2010 = pd.read_csv('ACS Data/DP03_2010.csv', low_memory=False)
acs04_2010 = pd.read_csv('ACS Data/DP04_2010.csv', low_memory=False)
acs05_2010 = pd.read_csv('ACS Data/DP05_2010.csv', low_memory=False)

# %%
yardi = pd.read_csv('yardi_cleaned_john.csv', low_memory=False)

# %%
##### 2022 ACS Variables #####
#DP02
dp02_2022_vars = ["GEO_ID",
	"NAME",
	"DP02_0001E", ## Total households
	"DP02_0016E", ## Avg household size
	"DP02_0017E", ## Avg family size
	"DP02_0044E", ## Gparents living with gchildren
	"DP02_0045E", ## Gparents responsible for gchildren
	"DP02_0059E", ## Aged 25+
	"DP02_0060E", ## <9th grade
	"DP02_0061E", ## 9th-12th grade, no diploma
	"DP02_0062E", ## HS grad
	"DP02_0063E", ## Some college, no deg
	"DP02_0064E", ## Associate's
	"DP02_0065E", ## Bachelor's
	"DP02_0066E", ## Grad/prof deg
	"DP02_0067E", ## HS grad or higher
	"DP02_0068E", ## Bachelor's or higher
	"DP02_0069E", ## Civilian pop aged 18+
	"DP02_0070E" ## Civilian veterans
]

#DP03
dp03_2022_vars = [
	"GEO_ID", 
	"NAME", 
	"DP03_0001E", ## Pop aged 16+
	"DP03_0002E", ## In labor force
	"DP03_0007E", ## Not in labor force
	"DP03_0009E", ## Unemployment rate
	"DP03_0011E", ## Females aged 16+ in labor force
	"DP03_0014E", ## Children of householder aged <6
	"DP03_0015E", ## Children of householder aged <6, all parents work
	"DP03_0016E", ## Children of householder aged 6-17
	"DP03_0017E", ## Children of householder aged 6-17, all parents work
	"DP03_0018E", ## Workers aged 16+
	"DP03_0019E", ## Commute - drove alone
	"DP03_0020E", ## Commute - carpool
	"DP03_0021E", ## Commute - public trans
	"DP03_0022E", ## Commute - walk
	"DP03_0023E", ## Commute - other means
	"DP03_0024E", ## Commute - work from home
	"DP03_0025E", ## Mean travel time to work
	"DP03_0026E", ## Civilian employed pop aged 16+
	"DP03_0028E", ## Occupation - service
	"DP03_0029E", ## Occupation - sales & office
	"DP03_0052E", ## Income - <10K
	"DP03_0053E", ## Income - 10K-14,999
	"DP03_0054E", ## Income - 15K-24,999
	"DP03_0055E", ## Income - 25K-34,999
	"DP03_0056E", ## Income - 35K-49,999
	"DP03_0062E", ## Median HH income
	"DP03_0063E", ## Mean HH income
	"DP03_0074E", ## Food stamp/SNAP in past year
	"DP03_0095E", ## Civilian noninstitutionalized pop
	"DP03_0096E", ## With health insurance
	"DP03_0097E", ## With private HI
	"DP03_0098E", ## With public HI
	"DP03_0099E", ## No health insurance
	"DP03_0119E"  ## Families below poverty line in past year
]

#DP04
dp04_2022_vars = [
	"GEO_ID", 
	"NAME", 
	"DP04_0001E", ## Total housing units
	"DP04_0002E", ## Occupied units
	"DP04_0047E", ## Renter-occupied
	"DP04_0136E", ## Occupied units paying rent
	"DP04_0137E", ## Rent - <15% of income
	"DP04_0138E", ## Rent - 15-19.9% of income
	"DP04_0139E", ## Rent - 20-24.9% of income
	"DP04_0140E", ## Rent - 25-29.9% of income
	"DP04_0141E", ## Rent - 30-34.9% of income
	"DP04_0142E", ## Rent - 35%+ of income
	"DP04_0143E", ## Rent - not computed
	"DP04_0007E", ## Units - 1, detached
	"DP04_0008E", ## Units - 1, attached
	"DP04_0009E", ## 2 units
	"DP04_0010E", ## 3 or 4 units
	"DP04_0011E", ## 5 to 9 units
	"DP04_0012E", ## 10 to 19 units
	"DP04_0013E", ## 20+ units
	"DP04_0017E", ## Built 2020 or later
	"DP04_0018E", ## Built 2010-2019
	"DP04_0025E", ## Built 1940-1949
	"DP04_0026E", ## Built 1939 or earlier
	"DP04_0039E", ## No bedroom
	"DP04_0040E", ## 1 bedroom
	"DP04_0041E", ## 2 bedrooms
	"DP04_0042E", ## 3 bedrooms
	"DP04_0043E", ## 4 bedrooms
	"DP04_0044E" ## 5+ bedrooms
]

#DP05
dp05_2022_vars = [
	"GEO_ID", 
	"NAME", 
	"DP05_0001E", ## Total pop
	"DP05_0009E", ## Aged 20-24
	"DP05_0010E", ## Aged 25-34
	"DP05_0018E", ## Median age
	"DP05_0019E", ## Aged <18
	"DP05_0021E", ## Aged 18+
	"DP05_0024E", ## Aged 65+
	"DP05_0067E", ## Black/African American
	"DP05_0068E", ## American Indian/Alaskan Native
	"DP05_0069E", ## Asian
	"DP05_0070E", ## Native Hawaiin/Pacific Islander
	"DP05_0071E", ## Some other race
	"DP05_0073E", ## Hispanic/Latino (any race)
	"DP05_0079E" ## White alone
]


##### 2010 ACS Variables #####
# DP02
dp02_2010_vars = [
	"GEO_ID",
	"NAME", 
	"DP02_0001E", ## Total households
	"DP02_0043E", ## Gparents living with gchildren
	"DP02_0044E", ## Gparents responsible for gchildren
	"DP02_0058E", ## Aged 25+
	"DP02_0059E", ## <9th grade
	"DP02_0060E", ## 9th-12th, no diploma
	"DP02_0061E", ## HS grad
	"DP02_0062E", ## Some college, no deg
	"DP02_0063E", ## Associate's
	"DP02_0064E", ## Bachelor's
	"DP02_0065E", ## Grad/prof degree
	"DP02_0068E", ## Civilian pop 18+
	"DP02_0069E" ## Civilian veterans
]

# DP03
dp03_2010_vars = [
	"GEO_ID", 
	"NAME",
	"DP03_0001E", ## Aged 16+
	"DP03_0002E", ## In labor force
	"DP03_0003E", ## Civilian labor force
	"DP03_0004E", ## Employed
	"DP03_0005E", ## Unemployed
	"DP03_0007E", ## Not in labor force
	#"DP03_0008E", ## Civilian labor force. Same as DP03_0003E
	"DP03_0010E", ## Females aged <16
	"DP03_0014E", ## Own children aged <6
	"DP03_0015E", ## All parents in labor force
	"DP03_0016E", ## Own children aged 6-17
	"DP03_0018E", ## Workers aged 16+
	"DP03_0019E", ## Commute - drove alone
	"DP03_0020E", ## Commute - carpool
	"DP03_0021E", ## Commute - public trans
	"DP03_0022E", ## Commute - Walk
	"DP03_0023E", ## Commute - Other means
	"DP03_0024E", ## Work from home
	"DP03_0025E", ## Mean travel time (min)
	"DP03_0026E", ## Employed civilians aged 16+
	"DP03_0028E", ## Occupation - service
	"DP03_0029E", ## Occupation - sales & office
	"DP03_0051E", ## Total households
	"DP03_0052E", ## Income <10K
	"DP03_0053E", ## Income 10K-14,999
	"DP03_0054E", ## Income 15K-24,999
	"DP03_0055E", ## Income 25K-34,999
	"DP03_0056E", ## Income 35K-49,999
	"DP03_0062E", ## Median HH income
	"DP03_0063E", ## Mean HH income
	"DP03_0065E", ## Mean earnings
	"DP03_0074E", ## Food stamp/SNAP in past year
	"DP03_0095E", ## Civilian noninstitutionalized pop
	"DP03_0096E", ## With health insurance
	"DP03_0097E", ## With private HI
	"DP03_0098E", ## With public HI
	"DP03_0099E", ## No health insurance
	"DP03_0119E" ## Families below poverty line in past year
]

# DP04
dp04_2010_vars = [
	"GEO_ID", 
	"NAME", 
	"DP04_0001E", ## Total housing units
	"DP04_0002E", ## Occupied housing units
	"DP04_0007E", ## Units - 1, detached
	"DP04_0008E", ## Units - 1, attached
	"DP04_0009E", ## 2 units
	"DP04_0010E", ## 3 or 4 units
	"DP04_0011E", ## 5 to 9 units
	"DP04_0012E", ## 10 to 19 units
	"DP04_0013E", ## 20+ units
	"DP04_0017E", ## Built 2005 or later
	"DP04_0018E", ## Built 2000-2004
	"DP04_0024E", ## Built 1940-1949
	"DP04_0025E", ## Built 1939 or earlier
	"DP04_0038E", ## No bedroom
	"DP04_0039E", ## 1 bedroom
	"DP04_0040E", ## 2 bedrooms
	"DP04_0041E", ## 3 bedrooms
	"DP04_0042E", ## 4 bedrooms
	"DP04_0043E", ## 5+ bedrooms
	"DP04_0046E", ## Renter-occupied
	"DP04_0048E", ## Avg household of renter occupied unit
	"DP04_0124E", ## Occupied units paying rent
	"DP04_0134E", ## Occupied units paying rent (excl. where GRAP cannot be computed)
	"DP04_0135E", ## Rent - <15% of income
	"DP04_0136E", ## Rent - 15-19.9% of income
	"DP04_0137E", ## Rent - 20-24.9% of income
	"DP04_0138E", ## Rent - 25-29.9% of income
	"DP04_0139E", ## Rent - 30-34.9% of income
	"DP04_0140E", ## Rent - 35%+ of income
	"DP04_0141E" ## Rent - not computed
]

# DP05
dp05_2010_vars = [
	"GEO_ID", 
	"NAME", 
	"DP05_0001E", ## Total pop
	"DP05_0008E", ## Aged 20-24
	"DP05_0009E", ## Aged 25-34
	"DP05_0018E", ## Aged 18+
	"DP05_0021E", ## Aged 65+
	"DP05_0060E", ## Black/African American
	"DP05_0061E", ## American Indian/Alaskan Native
	"DP05_0062E", ## Asian
	"DP05_0063E", ## Native Hawaiin/Pacific Islander
	"DP05_0064E", ## Some other race
	"DP05_0065E", ## Total pop
	"DP05_0066E", ## Hispanic/Latino (any race)
	"DP05_0071E", ## Not Hispanic/Latino
	"DP05_0072E" ## White alone
]

# %%
acs02_2022 = acs02_2022[dp02_2022_vars]
acs03_2022 = acs03_2022[dp03_2022_vars]
acs04_2022 = acs04_2022[dp04_2022_vars]
acs05_2022 = acs05_2022[dp05_2022_vars]

acs02_2010 = acs02_2010[dp02_2010_vars]
acs03_2010 = acs03_2010[dp03_2010_vars]
acs04_2010 = acs04_2010[dp04_2010_vars]
acs05_2010 = acs05_2010[dp05_2010_vars]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 4
#       2 acs03_2022 = acs03_2022[dp03_2022_vars]
#       3 acs04_2022 = acs04_2022[dp04_2022_vars]
# ----> 4 acs05_2022 = acs05_2022[dp05_2022_vars]
#       6 acs02_2010 = acs02_2010[dp02_2010_vars]
#       7 acs03_2010 = acs03_2010[dp03_2010_vars]
#
# File /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
# ...

# %%
acs0203_2022 = pd.merge(acs02_2022, acs03_2022, on='GEO_ID', how='inner')
acs0405_2022 = pd.merge(acs04_2022, acs05_2022, on='GEO_ID', how='inner')
acs_2022 = pd.merge(acs0203_2022, acs0405_2022, on='GEO_ID', how='inner')

acs0203_2010 = pd.merge(acs02_2010, acs03_2010, on='GEO_ID', how='inner')
acs0405_2010 = pd.merge(acs04_2010, acs05_2010, on='GEO_ID', how='inner')
acs_2010 = pd.merge(acs0203_2010, acs0405_2010, on='GEO_ID', how='inner')

# %%
#acs_2022.to_csv('select_vars_usa_2022.csv')
#acs_2010.to_csv('select_vars_usa_2010.csv')
# Downloaded these files and removed 1400000US from GEO_ID

# %%
select_vars_usa_2010 = pd.read_csv('select_vars_usa_2010.csv', low_memory=False)
select_vars_usa_2022 = pd.read_csv('select_vars_usa_2022.csv', low_memory=False)

geoids_to_submarkets = pd.read_csv('GEOIDs_to_submarkets.csv', low_memory=False)

# %%
# Change GEO_ID to int64
select_vars_usa_2010 = select_vars_usa_2010.iloc[1:]
select_vars_usa_2022 = select_vars_usa_2022.iloc[1:]

select_vars_usa_2010['GEO_ID'] = select_vars_usa_2010['GEO_ID'].astype('int64')
select_vars_usa_2022['GEO_ID'] = select_vars_usa_2022['GEO_ID'].astype('int64')

# %%
merged_df = pd.merge(select_vars_usa_2022, geoids_to_submarkets, left_on='GEO_ID', right_on='GEOID')
#merged_df.to_csv("merged_data_2022.csv", index=False)

merged_df = pd.merge(select_vars_usa_2010, geoids_to_submarkets, left_on='GEO_ID', right_on='GEOID')
#merged_df.to_csv("merged_data_2010.csv", index=False)

# %%
merged_data_2022 = pd.read_csv("merged_data_2022.csv")
merged_data_2010 = pd.read_csv("merged_data_2010.csv")

# %%
acs_yardi = pd.merge(merged_data_2022, yardi, left_on='submarket', right_on='Locality')

# %%
acs_yardi.to_csv('acs_and_yardi.csv')

# %%
acs_yardi_left_join = pd.merge(merged_data_2022, yardi, left_on='submarket', right_on='Locality', how="left")
acs_yardi_left_join.to_csv('acs_yardi_left_join.csv')
